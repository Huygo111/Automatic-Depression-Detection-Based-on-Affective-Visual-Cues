# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/edaic-aus-pose-gaze/312_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/451_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/338_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/325_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/673_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/308_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/449_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/314_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/633_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/306_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/448_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/344_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/337_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/467_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/416_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/382_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/335_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/411_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/384_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/470_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/434_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/691_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/444_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/435_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/689_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/478_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/474_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/364_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/404_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/482_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/472_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/363_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/468_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/466_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/442_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/358_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/316_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/637_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/456_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/327_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/305_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/396_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/375_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/371_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/304_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/310_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/430_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/436_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/354_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/641_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/360_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/319_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/429_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/410_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/450_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/346_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/698_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/440_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/333_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/323_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/336_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/431_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/491_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/412_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/381_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/441_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/329_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/328_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/445_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/680_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/419_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/324_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/696_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/389_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/357_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/348_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/300_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/390_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/458_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/408_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/339_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/383_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/417_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/414_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/463_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/640_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/301_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/485_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/476_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/439_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/422_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/391_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/309_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/428_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/420_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/688_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/492_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/415_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/421_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/684_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/699_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/471_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/315_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/407_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/465_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/303_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/677_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/331_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/374_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/395_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/636_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/446_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/402_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/461_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/659_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/418_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/365_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/705_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/486_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/379_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/437_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/457_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/490_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/423_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/604_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/351_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/481_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/320_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/340_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/649_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/475_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/386_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/617_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/350_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/367_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/317_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/661_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/488_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/311_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/602_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/377_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/313_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/359_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/321_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/658_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/455_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/426_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/373_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/682_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/302_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/352_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/345_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/366_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/378_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/483_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/424_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/399_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/454_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/332_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/489_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/469_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/638_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/397_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/427_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/372_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/473_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/401_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/425_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/393_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/361_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/376_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/362_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/443_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/385_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/409_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/403_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/624_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/453_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/405_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/347_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/477_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/356_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/368_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/452_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/655_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/432_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/343_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/413_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/484_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/330_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/459_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/388_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/370_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/318_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/447_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/322_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/326_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/487_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/716_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/462_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/334_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/369_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/438_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/380_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/433_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/387_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/709_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/406_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/480_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/355_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/341_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/479_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/400_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/349_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/307_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/353_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/464_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-aus-pose-gaze/392_OpenFace2.1.0_Pose_gaze_AUs.csv
# /kaggle/input/edaic-transcript/331_Transcript.csv
# /kaggle/input/edaic-transcript/448_Transcript.csv
# /kaggle/input/edaic-transcript/358_Transcript.csv
# /kaggle/input/edaic-transcript/310_Transcript.csv
# /kaggle/input/edaic-transcript/466_Transcript.csv
# /kaggle/input/edaic-transcript/309_Transcript.csv
# /kaggle/input/edaic-transcript/370_Transcript.csv
# /kaggle/input/edaic-transcript/424_Transcript.csv
# /kaggle/input/edaic-transcript/377_Transcript.csv
# /kaggle/input/edaic-transcript/415_Transcript.csv
# /kaggle/input/edaic-transcript/416_Transcript.csv
# /kaggle/input/edaic-transcript/362_Transcript.csv
# /kaggle/input/edaic-transcript/427_Transcript.csv
# /kaggle/input/edaic-transcript/340_Transcript.csv
# /kaggle/input/edaic-transcript/482_Transcript.csv
# /kaggle/input/edaic-transcript/451_Transcript.csv
# /kaggle/input/edaic-transcript/432_Transcript.csv
# /kaggle/input/edaic-transcript/492_Transcript.csv
# /kaggle/input/edaic-transcript/379_Transcript.csv
# /kaggle/input/edaic-transcript/439_Transcript.csv
# /kaggle/input/edaic-transcript/327_Transcript.csv
# /kaggle/input/edaic-transcript/372_Transcript.csv
# /kaggle/input/edaic-transcript/326_Transcript.csv
# /kaggle/input/edaic-transcript/314_Transcript.csv
# /kaggle/input/edaic-transcript/684_Transcript.csv
# /kaggle/input/edaic-transcript/469_Transcript.csv
# /kaggle/input/edaic-transcript/393_Transcript.csv
# /kaggle/input/edaic-transcript/366_Transcript.csv
# /kaggle/input/edaic-transcript/341_Transcript.csv
# /kaggle/input/edaic-transcript/371_Transcript.csv
# /kaggle/input/edaic-transcript/459_Transcript.csv
# /kaggle/input/edaic-transcript/404_Transcript.csv
# /kaggle/input/edaic-transcript/395_Transcript.csv
# /kaggle/input/edaic-transcript/677_Transcript.csv
# /kaggle/input/edaic-transcript/474_Transcript.csv
# /kaggle/input/edaic-transcript/361_Transcript.csv
# /kaggle/input/edaic-transcript/336_Transcript.csv
# /kaggle/input/edaic-transcript/433_Transcript.csv
# /kaggle/input/edaic-transcript/396_Transcript.csv
# /kaggle/input/edaic-transcript/357_Transcript.csv
# /kaggle/input/edaic-transcript/418_Transcript.csv
# /kaggle/input/edaic-transcript/302_Transcript.csv
# /kaggle/input/edaic-transcript/301_Transcript.csv
# /kaggle/input/edaic-transcript/384_Transcript.csv
# /kaggle/input/edaic-transcript/468_Transcript.csv
# /kaggle/input/edaic-transcript/716_Transcript.csv
# /kaggle/input/edaic-transcript/423_Transcript.csv
# /kaggle/input/edaic-transcript/442_Transcript.csv
# /kaggle/input/edaic-transcript/360_Transcript.csv
# /kaggle/input/edaic-transcript/324_Transcript.csv
# /kaggle/input/edaic-transcript/488_Transcript.csv
# /kaggle/input/edaic-transcript/434_Transcript.csv
# /kaggle/input/edaic-transcript/304_Transcript.csv
# /kaggle/input/edaic-transcript/465_Transcript.csv
# /kaggle/input/edaic-transcript/320_Transcript.csv
# /kaggle/input/edaic-transcript/462_Transcript.csv
# /kaggle/input/edaic-transcript/441_Transcript.csv
# /kaggle/input/edaic-transcript/698_Transcript.csv
# /kaggle/input/edaic-transcript/490_Transcript.csv
# /kaggle/input/edaic-transcript/312_Transcript.csv
# /kaggle/input/edaic-transcript/328_Transcript.csv
# /kaggle/input/edaic-transcript/348_Transcript.csv
# /kaggle/input/edaic-transcript/344_Transcript.csv
# /kaggle/input/edaic-transcript/655_Transcript.csv
# /kaggle/input/edaic-transcript/400_Transcript.csv
# /kaggle/input/edaic-transcript/417_Transcript.csv
# /kaggle/input/edaic-transcript/338_Transcript.csv
# /kaggle/input/edaic-transcript/376_Transcript.csv
# /kaggle/input/edaic-transcript/311_Transcript.csv
# /kaggle/input/edaic-transcript/407_Transcript.csv
# /kaggle/input/edaic-transcript/351_Transcript.csv
# /kaggle/input/edaic-transcript/319_Transcript.csv
# /kaggle/input/edaic-transcript/325_Transcript.csv
# /kaggle/input/edaic-transcript/425_Transcript.csv
# /kaggle/input/edaic-transcript/337_Transcript.csv
# /kaggle/input/edaic-transcript/359_Transcript.csv
# /kaggle/input/edaic-transcript/450_Transcript.csv
# /kaggle/input/edaic-transcript/349_Transcript.csv
# /kaggle/input/edaic-transcript/440_Transcript.csv
# /kaggle/input/edaic-transcript/401_Transcript.csv
# /kaggle/input/edaic-transcript/480_Transcript.csv
# /kaggle/input/edaic-transcript/489_Transcript.csv
# /kaggle/input/edaic-transcript/364_Transcript.csv
# /kaggle/input/edaic-transcript/431_Transcript.csv
# /kaggle/input/edaic-transcript/305_Transcript.csv
# /kaggle/input/edaic-transcript/403_Transcript.csv
# /kaggle/input/edaic-transcript/356_Transcript.csv
# /kaggle/input/edaic-transcript/355_Transcript.csv
# /kaggle/input/edaic-transcript/421_Transcript.csv
# /kaggle/input/edaic-transcript/443_Transcript.csv
# /kaggle/input/edaic-transcript/317_Transcript.csv
# /kaggle/input/edaic-transcript/388_Transcript.csv
# /kaggle/input/edaic-transcript/436_Transcript.csv
# /kaggle/input/edaic-transcript/378_Transcript.csv
# /kaggle/input/edaic-transcript/346_Transcript.csv
# /kaggle/input/edaic-transcript/637_Transcript.csv
# /kaggle/input/edaic-transcript/438_Transcript.csv
# /kaggle/input/edaic-transcript/316_Transcript.csv
# /kaggle/input/edaic-transcript/321_Transcript.csv
# /kaggle/input/edaic-transcript/322_Transcript.csv
# /kaggle/input/edaic-transcript/405_Transcript.csv
# /kaggle/input/edaic-transcript/649_Transcript.csv
# /kaggle/input/edaic-transcript/387_Transcript.csv
# /kaggle/input/edaic-transcript/638_Transcript.csv
# /kaggle/input/edaic-transcript/641_Transcript.csv
# /kaggle/input/edaic-transcript/636_Transcript.csv
# /kaggle/input/edaic-transcript/380_Transcript.csv
# /kaggle/input/edaic-transcript/483_Transcript.csv
# /kaggle/input/edaic-transcript/420_Transcript.csv
# /kaggle/input/edaic-transcript/461_Transcript.csv
# /kaggle/input/edaic-transcript/633_Transcript.csv
# /kaggle/input/edaic-transcript/339_Transcript.csv
# /kaggle/input/edaic-transcript/658_Transcript.csv
# /kaggle/input/edaic-transcript/390_Transcript.csv
# /kaggle/input/edaic-transcript/307_Transcript.csv
# /kaggle/input/edaic-transcript/303_Transcript.csv
# /kaggle/input/edaic-transcript/373_Transcript.csv
# /kaggle/input/edaic-transcript/333_Transcript.csv
# /kaggle/input/edaic-transcript/386_Transcript.csv
# /kaggle/input/edaic-transcript/397_Transcript.csv
# /kaggle/input/edaic-transcript/306_Transcript.csv
# /kaggle/input/edaic-transcript/315_Transcript.csv
# /kaggle/input/edaic-transcript/382_Transcript.csv
# /kaggle/input/edaic-transcript/691_Transcript.csv
# /kaggle/input/edaic-transcript/363_Transcript.csv
# /kaggle/input/edaic-transcript/481_Transcript.csv
# /kaggle/input/edaic-transcript/369_Transcript.csv
# /kaggle/input/edaic-transcript/475_Transcript.csv
# /kaggle/input/edaic-transcript/464_Transcript.csv
# /kaggle/input/edaic-transcript/422_Transcript.csv
# /kaggle/input/edaic-transcript/659_Transcript.csv
# /kaggle/input/edaic-transcript/345_Transcript.csv
# /kaggle/input/edaic-transcript/409_Transcript.csv
# /kaggle/input/edaic-transcript/414_Transcript.csv
# /kaggle/input/edaic-transcript/479_Transcript.csv
# /kaggle/input/edaic-transcript/347_Transcript.csv
# /kaggle/input/edaic-transcript/430_Transcript.csv
# /kaggle/input/edaic-transcript/323_Transcript.csv
# /kaggle/input/edaic-transcript/350_Transcript.csv
# /kaggle/input/edaic-transcript/446_Transcript.csv
# /kaggle/input/edaic-transcript/352_Transcript.csv
# /kaggle/input/edaic-transcript/602_Transcript.csv
# /kaggle/input/edaic-transcript/452_Transcript.csv
# /kaggle/input/edaic-transcript/680_Transcript.csv
# /kaggle/input/edaic-transcript/429_Transcript.csv
# /kaggle/input/edaic-transcript/705_Transcript.csv
# /kaggle/input/edaic-transcript/624_Transcript.csv
# /kaggle/input/edaic-transcript/476_Transcript.csv
# /kaggle/input/edaic-transcript/353_Transcript.csv
# /kaggle/input/edaic-transcript/406_Transcript.csv
# /kaggle/input/edaic-transcript/385_Transcript.csv
# /kaggle/input/edaic-transcript/457_Transcript.csv
# /kaggle/input/edaic-transcript/455_Transcript.csv
# /kaggle/input/edaic-transcript/368_Transcript.csv
# /kaggle/input/edaic-transcript/426_Transcript.csv
# /kaggle/input/edaic-transcript/318_Transcript.csv
# /kaggle/input/edaic-transcript/478_Transcript.csv
# /kaggle/input/edaic-transcript/332_Transcript.csv
# /kaggle/input/edaic-transcript/428_Transcript.csv
# /kaggle/input/edaic-transcript/688_Transcript.csv
# /kaggle/input/edaic-transcript/473_Transcript.csv
# /kaggle/input/edaic-transcript/411_Transcript.csv
# /kaggle/input/edaic-transcript/392_Transcript.csv
# /kaggle/input/edaic-transcript/491_Transcript.csv
# /kaggle/input/edaic-transcript/673_Transcript.csv
# /kaggle/input/edaic-transcript/471_Transcript.csv
# /kaggle/input/edaic-transcript/445_Transcript.csv
# /kaggle/input/edaic-transcript/447_Transcript.csv
# /kaggle/input/edaic-transcript/308_Transcript.csv
# /kaggle/input/edaic-transcript/453_Transcript.csv
# /kaggle/input/edaic-transcript/484_Transcript.csv
# /kaggle/input/edaic-transcript/330_Transcript.csv
# /kaggle/input/edaic-transcript/413_Transcript.csv
# /kaggle/input/edaic-transcript/477_Transcript.csv
# /kaggle/input/edaic-transcript/391_Transcript.csv
# /kaggle/input/edaic-transcript/661_Transcript.csv
# /kaggle/input/edaic-transcript/604_Transcript.csv
# /kaggle/input/edaic-transcript/640_Transcript.csv
# /kaggle/input/edaic-transcript/449_Transcript.csv
# /kaggle/input/edaic-transcript/374_Transcript.csv
# /kaggle/input/edaic-transcript/456_Transcript.csv
# /kaggle/input/edaic-transcript/365_Transcript.csv
# /kaggle/input/edaic-transcript/408_Transcript.csv
# /kaggle/input/edaic-transcript/329_Transcript.csv
# /kaggle/input/edaic-transcript/383_Transcript.csv
# /kaggle/input/edaic-transcript/709_Transcript.csv
# /kaggle/input/edaic-transcript/334_Transcript.csv
# /kaggle/input/edaic-transcript/419_Transcript.csv
# /kaggle/input/edaic-transcript/467_Transcript.csv
# /kaggle/input/edaic-transcript/458_Transcript.csv
# /kaggle/input/edaic-transcript/367_Transcript.csv
# /kaggle/input/edaic-transcript/343_Transcript.csv
# /kaggle/input/edaic-transcript/412_Transcript.csv
# /kaggle/input/edaic-transcript/485_Transcript.csv
# /kaggle/input/edaic-transcript/463_Transcript.csv
# /kaggle/input/edaic-transcript/682_Transcript.csv
# /kaggle/input/edaic-transcript/399_Transcript.csv
# /kaggle/input/edaic-transcript/354_Transcript.csv
# /kaggle/input/edaic-transcript/381_Transcript.csv
# /kaggle/input/edaic-transcript/470_Transcript.csv
# /kaggle/input/edaic-transcript/486_Transcript.csv
# /kaggle/input/edaic-transcript/313_Transcript.csv
# /kaggle/input/edaic-transcript/410_Transcript.csv
# /kaggle/input/edaic-transcript/402_Transcript.csv
# /kaggle/input/edaic-transcript/617_Transcript.csv
# /kaggle/input/edaic-transcript/472_Transcript.csv
# /kaggle/input/edaic-transcript/300_Transcript.csv
# /kaggle/input/edaic-transcript/689_Transcript.csv
# /kaggle/input/edaic-transcript/696_Transcript.csv
# /kaggle/input/edaic-transcript/444_Transcript.csv
# /kaggle/input/edaic-transcript/375_Transcript.csv
# /kaggle/input/edaic-transcript/487_Transcript.csv
# /kaggle/input/edaic-transcript/454_Transcript.csv
# /kaggle/input/edaic-transcript/389_Transcript.csv
# /kaggle/input/edaic-transcript/699_Transcript.csv
# /kaggle/input/edaic-transcript/435_Transcript.csv
# /kaggle/input/edaic-transcript/335_Transcript.csv
# /kaggle/input/edaic-transcript/437_Transcript.csv

# %%
import pandas as pd
import os


def split_openface_by_transcript(transcript_path, openface_path, output_dir=None, segment_duration=30):
    """
    Cắt file OpenFace thành các đoạn 30s dựa trên khoảng thời gian từ file Transcript.
    
    Parameters:
    -----------
    transcript_path : str
        Đường dẫn đến file CSV Transcript (chứa Start_Time và End_Time)
    openface_path : str
        Đường dẫn đến file CSV OpenFace (chứa cột timestamp)
    output_dir : str, optional
        Thư mục lưu các file output. Nếu None, tạo thư mục mới tên 'output_segments'
    segment_duration : int, optional
        Độ dài mỗi đoạn (giây), mặc định 30s
    
    Returns:
    --------
    list
        Danh sách đường dẫn các file đã tạo
    """
    
    # Lấy prefix từ tên file transcript (ví dụ: 300_Transcript.csv -> 300)
    transcript_filename = os.path.basename(transcript_path)
    file_prefix = transcript_filename.split('_')[0]
    print(f"File prefix: {file_prefix}")
    
    # Đọc file transcript
    transcript_df = pd.read_csv(transcript_path)
    
    # Lấy Start_Time đầu tiên và End_Time cuối cùng
    start_time = transcript_df['Start_Time'].min()
    end_time = transcript_df['End_Time'].max()
    
    print(f"Khoảng thời gian từ Transcript: {start_time}s - {end_time}s")
    
    # Đọc file OpenFace
    openface_df = pd.read_csv(openface_path)
    
    # Lọc dữ liệu OpenFace theo khoảng thời gian từ Transcript
    filtered_df = openface_df[
        (openface_df['timestamp'] >= start_time) & 
        (openface_df['timestamp'] <= end_time)
    ].copy()
    
    print(f"Số dòng OpenFace sau khi lọc: {len(filtered_df)}")
    
    # Tạo thư mục output nếu chưa có
    if output_dir is None:
        output_dir = 'output_segments'
    os.makedirs(output_dir, exist_ok=True)
    
    # Cắt thành các đoạn 30s
    output_files = []
    segment_start = start_time
    segment_index = 1
    
    while segment_start < end_time:
        segment_end = segment_start + segment_duration
        
        # Bỏ qua segment cuối nếu ngắn hơn 30s
        if segment_end > end_time:
            remaining = end_time - segment_start
            if remaining < segment_duration:
                print(f"Bỏ qua segment cuối ({remaining:.1f}s < {segment_duration}s)")
                break
            segment_end = end_time
        
        # Lọc dữ liệu cho đoạn hiện tại
        segment_df = filtered_df[
            (filtered_df['timestamp'] >= segment_start) & 
            (filtered_df['timestamp'] < segment_end)
        ].copy()
        
        # Lưu số hàng ban đầu
        original_rows = len(segment_df)
        
        # Lọc bỏ các hàng có success = 0 hoặc confidence < 0.9
        segment_df = segment_df[
            (segment_df['success'] == 1) & 
            (segment_df['confidence'] >= 0.9)
        ]
        
        # Tính số hàng bị loại bỏ
        removed_rows = original_rows - len(segment_df)
        
        # Bỏ qua segment nếu có nhiều hơn 30 hàng bị loại
        if removed_rows > 30:
            print(f"Bỏ qua segment {segment_index:03d} (loại bỏ {removed_rows} hàng > 30)")
            segment_start = segment_end
            segment_index += 1
            continue
        
        # Lưu file nếu đoạn có dữ liệu
        if len(segment_df) > 0:
            # Tạo tên file với format: 300_segment_001.csv
            output_filename = f"{file_prefix}_segment_{segment_index:03d}.csv"
            output_path = os.path.join(output_dir, output_filename)
            
            segment_df.to_csv(output_path, index=False)
            output_files.append(output_path)
            
            print(f"Đã tạo: {output_filename} ({len(segment_df)} hàng, loại bỏ {removed_rows} hàng)")
        
        segment_start = segment_end
        segment_index += 1
    
    print(f"\nĐã tạo tổng cộng {len(output_files)} file segment")
    return output_files


def batch_process_files(transcript_dir, openface_dir, output_base_dir, start_id=300, end_id=716, segment_duration=30):
    """
    Xử lý hàng loạt file từ start_id đến end_id.
    
    Parameters:
    -----------
    transcript_dir : str
        Thư mục chứa các file Transcript
    openface_dir : str
        Thư mục chứa các file OpenFace
    output_base_dir : str
        Thư mục gốc để lưu output
    start_id : int
        ID bắt đầu (mặc định 300)
    end_id : int
        ID kết thúc (mặc định 716)
    segment_duration : int
        Độ dài mỗi segment (giây)
    
    Returns:
    --------
    dict
        Dictionary với key là file_id và value là danh sách file segments đã tạo
    """
    
    results = {}
    processed_count = 0
    skipped_count = 0
    
    print(f"Bắt đầu xử lý từ ID {start_id} đến {end_id}\n")
    print("=" * 80)
    
    for file_id in range(start_id, end_id + 1):
        # Tạo đường dẫn file
        transcript_path = os.path.join(transcript_dir, f"{file_id}_Transcript.csv")
        openface_path = os.path.join(openface_dir, f"{file_id}_OpenFace2.1.0_Pose_gaze_AUs.csv")
        
        # Kiểm tra cả 2 file có tồn tại không
        if not os.path.exists(transcript_path):
            print(f"⊘ Bỏ qua {file_id}: Không tìm thấy file Transcript")
            skipped_count += 1
            continue
            
        if not os.path.exists(openface_path):
            print(f"⊘ Bỏ qua {file_id}: Không tìm thấy file OpenFace")
            skipped_count += 1
            continue
        
        # Tạo thư mục output cho file này (VD: 300_P)
        output_dir = os.path.join(output_base_dir, f"{file_id}_P")
        
        print(f"\n► Đang xử lý ID {file_id}...")
        
        try:
            # Gọi hàm xử lý
            output_files = split_openface_by_transcript(
                transcript_path=transcript_path,
                openface_path=openface_path,
                output_dir=output_dir,
                segment_duration=segment_duration
            )
            
            results[file_id] = output_files
            processed_count += 1
            print(f"✓ Hoàn thành ID {file_id}: {len(output_files)} segments")
            
        except Exception as e:
            print(f"✗ Lỗi khi xử lý ID {file_id}: {str(e)}")
            skipped_count += 1
            continue
    
    print("\n" + "=" * 80)
    print(f"\nTÓM TẮT:")
    print(f"  • Đã xử lý thành công: {processed_count} files")
    print(f"  • Đã bỏ qua: {skipped_count} files")
    print(f"  • Tổng segments tạo ra: {sum(len(files) for files in results.values())}")
    
    return results


# Ví dụ sử dụng batch processing
if __name__ == "__main__":
    # Cấu hình đường dẫn
    TRANSCRIPT_DIR = "/kaggle/input/edaic-transcript"
    OPENFACE_DIR = "/kaggle/input/edaic-aus-pose-gaze"
    OUTPUT_BASE_DIR = "/kaggle/working"
    
    # Chạy batch processing
    results = batch_process_files(
        transcript_dir=TRANSCRIPT_DIR,
        openface_dir=OPENFACE_DIR,
        output_base_dir=OUTPUT_BASE_DIR,
        start_id=300,
        end_id=716,
        segment_duration=30
    )
    
    # In kết quả chi tiết (tùy chọn)
    print("\n" + "=" * 80)
    print("CHI TIẾT KẾT QUẢ:")
    for file_id, files in sorted(results.items()):
        print(f"  {file_id}_P: {len(files)} segments")
# Out:
# Bắt đầu xử lý từ ID 300 đến 716
#
# ================================================================================
#
# ► Đang xử lý ID 300...
# File prefix: 300
# Khoảng thời gian từ Transcript: 14.3s - 648.3s
# Số dòng OpenFace sau khi lọc: 19021
# Bỏ qua segment 001 (loại bỏ 67 hàng > 30)
# Đã tạo: 300_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_016.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 300_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 300_segment_019.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 300_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 021 (loại bỏ 46 hàng > 30)
# Bỏ qua segment cuối (4.0s < 30s)
#
# Đã tạo tổng cộng 19 file segment
# ✓ Hoàn thành ID 300: 19 segments
#
# ► Đang xử lý ID 301...
# File prefix: 301
# Khoảng thời gian từ Transcript: 0.8s - 822.9s
# Số dòng OpenFace sau khi lọc: 24664
# Đã tạo: 301_segment_001.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 301_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 301_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (12.1s < 30s)
#
# Đã tạo tổng cộng 27 file segment
# ✓ Hoàn thành ID 301: 27 segments
#
# ► Đang xử lý ID 302...
# File prefix: 302
# Khoảng thời gian từ Transcript: 2.1s - 756.4s
# Số dòng OpenFace sau khi lọc: 22630
# Bỏ qua segment 001 (loại bỏ 48 hàng > 30)
# Đã tạo: 302_segment_002.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 302_segment_003.csv (874 hàng, loại bỏ 26 hàng)
# Đã tạo: 302_segment_004.csv (891 hàng, loại bỏ 9 hàng)
# Bỏ qua segment 005 (loại bỏ 54 hàng > 30)
# Đã tạo: 302_segment_006.csv (885 hàng, loại bỏ 15 hàng)
# Bỏ qua segment 007 (loại bỏ 44 hàng > 30)
# Đã tạo: 302_segment_008.csv (887 hàng, loại bỏ 13 hàng)
# Bỏ qua segment 009 (loại bỏ 45 hàng > 30)
# Đã tạo: 302_segment_010.csv (891 hàng, loại bỏ 9 hàng)
# Bỏ qua segment 011 (loại bỏ 48 hàng > 30)
# Đã tạo: 302_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 013 (loại bỏ 39 hàng > 30)
# Đã tạo: 302_segment_014.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 302_segment_015.csv (892 hàng, loại bỏ 8 hàng)
# Bỏ qua segment 016 (loại bỏ 58 hàng > 30)
# Đã tạo: 302_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 302_segment_018.csv (873 hàng, loại bỏ 27 hàng)
# Đã tạo: 302_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 302_segment_020.csv (886 hàng, loại bỏ 14 hàng)
# Đã tạo: 302_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 302_segment_022.csv (895 hàng, loại bỏ 5 hàng)
# Bỏ qua segment 023 (loại bỏ 209 hàng > 30)
# Bỏ qua segment 024 (loại bỏ 681 hàng > 30)
# Bỏ qua segment 025 (loại bỏ 519 hàng > 30)
# Bỏ qua segment cuối (4.3s < 30s)
#
# Đã tạo tổng cộng 15 file segment
# ✓ Hoàn thành ID 302: 15 segments
#
# ► Đang xử lý ID 303...
# File prefix: 303
# Khoảng thời gian từ Transcript: 1.3s - 983.0s
# Số dòng OpenFace sau khi lọc: 29452
# Đã tạo: 303_segment_001.csv (884 hàng, loại bỏ 16 hàng)
# Đã tạo: 303_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_003.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 303_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_006.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 303_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_010.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 303_segment_011.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 303_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_013.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 303_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_015.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 303_segment_016.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 303_segment_017.csv (885 hàng, loại bỏ 15 hàng)
# Bỏ qua segment 018 (loại bỏ 126 hàng > 30)
# Đã tạo: 303_segment_019.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 303_segment_020.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 303_segment_021.csv (893 hàng, loại bỏ 7 hàng)
# Bỏ qua segment 022 (loại bỏ 41 hàng > 30)
# Đã tạo: 303_segment_023.csv (886 hàng, loại bỏ 14 hàng)
# Đã tạo: 303_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 303_segment_025.csv (890 hàng, loại bỏ 10 hàng)
# Đã tạo: 303_segment_026.csv (877 hàng, loại bỏ 23 hàng)
# Bỏ qua segment 027 (loại bỏ 32 hàng > 30)
# Đã tạo: 303_segment_028.csv (892 hàng, loại bỏ 8 hàng)
# Bỏ qua segment 029 (loại bỏ 110 hàng > 30)
# Bỏ qua segment 030 (loại bỏ 117 hàng > 30)
# Đã tạo: 303_segment_031.csv (876 hàng, loại bỏ 24 hàng)
# Đã tạo: 303_segment_032.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (21.7s < 30s)
#
# Đã tạo tổng cộng 27 file segment
# ✓ Hoàn thành ID 303: 27 segments
#
# ► Đang xử lý ID 304...
# File prefix: 304
# Khoảng thời gian từ Transcript: 2.0s - 786.4s
# Số dòng OpenFace sau khi lọc: 23533
# Đã tạo: 304_segment_001.csv (870 hàng, loại bỏ 30 hàng)
# Đã tạo: 304_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 304_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 304_segment_004.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 304_segment_005.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 304_segment_006.csv (895 hàng, loại bỏ 5 hàng)
# Bỏ qua segment 007 (loại bỏ 60 hàng > 30)
# Bỏ qua segment 008 (loại bỏ 105 hàng > 30)
# Đã tạo: 304_segment_009.csv (872 hàng, loại bỏ 28 hàng)
# Bỏ qua segment 010 (loại bỏ 31 hàng > 30)
# Đã tạo: 304_segment_011.csv (876 hàng, loại bỏ 24 hàng)
# Bỏ qua segment 012 (loại bỏ 68 hàng > 30)
# Bỏ qua segment 013 (loại bỏ 63 hàng > 30)
# Bỏ qua segment 014 (loại bỏ 52 hàng > 30)
# Bỏ qua segment 015 (loại bỏ 67 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 111 hàng > 30)
# Bỏ qua segment 017 (loại bỏ 72 hàng > 30)
# Bỏ qua segment 018 (loại bỏ 272 hàng > 30)
# Bỏ qua segment 019 (loại bỏ 43 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 83 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 49 hàng > 30)
# Bỏ qua segment 022 (loại bỏ 40 hàng > 30)
# Bỏ qua segment 023 (loại bỏ 39 hàng > 30)
# Đã tạo: 304_segment_024.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 304_segment_025.csv (899 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 026 (loại bỏ 286 hàng > 30)
# Bỏ qua segment cuối (4.4s < 30s)
#
# Đã tạo tổng cộng 10 file segment
# ✓ Hoàn thành ID 304: 10 segments
#
# ► Đang xử lý ID 305...
# File prefix: 305
# Khoảng thời gian từ Transcript: 0.6000000000000001s - 1703.9s
# Số dòng OpenFace sau khi lọc: 51099
# Đã tạo: 305_segment_001.csv (886 hàng, loại bỏ 13 hàng)
# Đã tạo: 305_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_011.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 305_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_016.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 305_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_028.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_029.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_030.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_031.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_032.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_033.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_034.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_035.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_036.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_037.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_038.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_039.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 040 (loại bỏ 50 hàng > 30)
# Bỏ qua segment 041 (loại bỏ 313 hàng > 30)
# Đã tạo: 305_segment_042.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_043.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_044.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_045.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_046.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_047.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_048.csv (886 hàng, loại bỏ 14 hàng)
# Đã tạo: 305_segment_049.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_050.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_051.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_052.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_053.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_054.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 305_segment_055.csv (887 hàng, loại bỏ 13 hàng)
# Đã tạo: 305_segment_056.csv (896 hàng, loại bỏ 4 hàng)
# Bỏ qua segment cuối (23.3s < 30s)
#
# Đã tạo tổng cộng 54 file segment
# ✓ Hoàn thành ID 305: 54 segments
#
# ► Đang xử lý ID 306...
# File prefix: 306
# Khoảng thời gian từ Transcript: 0.3s - 853.2s
# Số dòng OpenFace sau khi lọc: 25588
# Đã tạo: 306_segment_001.csv (871 hàng, loại bỏ 29 hàng)
# Đã tạo: 306_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_007.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 306_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_019.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 306_segment_020.csv (877 hàng, loại bỏ 23 hàng)
# Đã tạo: 306_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 306_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 028 (loại bỏ 75 hàng > 30)
# Bỏ qua segment cuối (12.9s < 30s)
#
# Đã tạo tổng cộng 27 file segment
# ✓ Hoàn thành ID 306: 27 segments
#
# ► Đang xử lý ID 307...
# File prefix: 307
# Khoảng thời gian từ Transcript: 0.1s - 1237.4s
# Số dòng OpenFace sau khi lọc: 37120
# Bỏ qua segment 001 (loại bỏ 110 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 53 hàng > 30)
# Đã tạo: 307_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_004.csv (897 hàng, loại bỏ 3 hàng)
# Bỏ qua segment 005 (loại bỏ 47 hàng > 30)
# Đã tạo: 307_segment_006.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 307_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_009.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 307_segment_010.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 307_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_012.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 307_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_014.csv (893 hàng, loại bỏ 7 hàng)
# Bỏ qua segment 015 (loại bỏ 35 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 50 hàng > 30)
# Đã tạo: 307_segment_017.csv (875 hàng, loại bỏ 25 hàng)
# Bỏ qua segment 018 (loại bỏ 33 hàng > 30)
# Đã tạo: 307_segment_019.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 307_segment_020.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 307_segment_021.csv (889 hàng, loại bỏ 11 hàng)
# Đã tạo: 307_segment_022.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 307_segment_023.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 307_segment_024.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 307_segment_025.csv (871 hàng, loại bỏ 29 hàng)
# Đã tạo: 307_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 027 (loại bỏ 36 hàng > 30)
# Đã tạo: 307_segment_028.csv (892 hàng, loại bỏ 8 hàng)
# Đã tạo: 307_segment_029.csv (870 hàng, loại bỏ 30 hàng)
# Đã tạo: 307_segment_030.csv (883 hàng, loại bỏ 17 hàng)
# Đã tạo: 307_segment_031.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 307_segment_032.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 307_segment_033.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 307_segment_034.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 307_segment_035.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 307_segment_036.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 307_segment_037.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 307_segment_038.csv (875 hàng, loại bỏ 25 hàng)
# Đã tạo: 307_segment_039.csv (880 hàng, loại bỏ 20 hàng)
# Đã tạo: 307_segment_040.csv (896 hàng, loại bỏ 4 hàng)
# Bỏ qua segment 041 (loại bỏ 430 hàng > 30)
# Bỏ qua segment cuối (7.3s < 30s)
#
# Đã tạo tổng cộng 33 file segment
# ✓ Hoàn thành ID 307: 33 segments
#
# ► Đang xử lý ID 308...
# File prefix: 308
# Khoảng thời gian từ Transcript: 0.0s - 838.5s
# Số dòng OpenFace sau khi lọc: 25156
# Bỏ qua segment 001 (loại bỏ 40 hàng > 30)
# Đã tạo: 308_segment_002.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 308_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_009.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 308_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 011 (loại bỏ 113 hàng > 30)
# Bỏ qua segment 012 (loại bỏ 98 hàng > 30)
# Đã tạo: 308_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_014.csv (888 hàng, loại bỏ 12 hàng)
# Bỏ qua segment 015 (loại bỏ 80 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 47 hàng > 30)
# Đã tạo: 308_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 024 (loại bỏ 71 hàng > 30)
# Đã tạo: 308_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 308_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (28.5s < 30s)
#
# Đã tạo tổng cộng 21 file segment
# ✓ Hoàn thành ID 308: 21 segments
#
# ► Đang xử lý ID 309...
# File prefix: 309
# Khoảng thời gian từ Transcript: 5.4s - 697.1s
# Số dòng OpenFace sau khi lọc: 20964
# Bỏ qua segment 001 (loại bỏ 45 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 78 hàng > 30)
# Đã tạo: 309_segment_003.csv (908 hàng, loại bỏ 1 hàng)
# Đã tạo: 309_segment_004.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_006.csv (900 hàng, loại bỏ 9 hàng)
# Đã tạo: 309_segment_007.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_008.csv (908 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 009 (loại bỏ 35 hàng > 30)
# Đã tạo: 309_segment_010.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 309_segment_011.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_012.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_013.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_016.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_017.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 309_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_019.csv (892 hàng, loại bỏ 17 hàng)
# Đã tạo: 309_segment_020.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 309_segment_021.csv (910 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 022 (loại bỏ 77 hàng > 30)
# Bỏ qua segment 023 (loại bỏ 147 hàng > 30)
# Bỏ qua segment cuối (1.7s < 30s)
#
# Đã tạo tổng cộng 18 file segment
# ✓ Hoàn thành ID 309: 18 segments
#
# ► Đang xử lý ID 310...
# File prefix: 310
# Khoảng thời gian từ Transcript: 55.5s - 815.4s
# Số dòng OpenFace sau khi lọc: 23032
# Đã tạo: 310_segment_001.csv (905 hàng, loại bỏ 4 hàng)
# Bỏ qua segment 002 (loại bỏ 52 hàng > 30)
# Bỏ qua segment 003 (loại bỏ 162 hàng > 30)
# Đã tạo: 310_segment_004.csv (891 hàng, loại bỏ 18 hàng)
# Bỏ qua segment 005 (loại bỏ 135 hàng > 30)
# Bỏ qua segment 006 (loại bỏ 142 hàng > 30)
# Bỏ qua segment 007 (loại bỏ 177 hàng > 30)
# Bỏ qua segment 008 (loại bỏ 549 hàng > 30)
# Đã tạo: 310_segment_009.csv (882 hàng, loại bỏ 27 hàng)
# Bỏ qua segment 010 (loại bỏ 103 hàng > 30)
# Bỏ qua segment 011 (loại bỏ 185 hàng > 30)
# Bỏ qua segment 012 (loại bỏ 80 hàng > 30)
# Bỏ qua segment 013 (loại bỏ 60 hàng > 30)
# Bỏ qua segment 014 (loại bỏ 119 hàng > 30)
# Bỏ qua segment 015 (loại bỏ 279 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 293 hàng > 30)
# Bỏ qua segment 017 (loại bỏ 87 hàng > 30)
# Bỏ qua segment 018 (loại bỏ 118 hàng > 30)
# Bỏ qua segment 019 (loại bỏ 409 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 236 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 476 hàng > 30)
# Bỏ qua segment 022 (loại bỏ 113 hàng > 30)
# Bỏ qua segment 023 (loại bỏ 258 hàng > 30)
# Bỏ qua segment 024 (loại bỏ 316 hàng > 30)
# Bỏ qua segment 025 (loại bỏ 363 hàng > 30)
# Bỏ qua segment cuối (9.9s < 30s)
#
# Đã tạo tổng cộng 3 file segment
# ✓ Hoàn thành ID 310: 3 segments
#
# ► Đang xử lý ID 311...
# File prefix: 311
# Khoảng thời gian từ Transcript: 17.7s - 763.9s
# Số dòng OpenFace sau khi lọc: 22616
# Đã tạo: 311_segment_001.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_002.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_003.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_004.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_006.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_007.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_008.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_009.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_010.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_011.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_012.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_013.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_015.csv (901 hàng, loại bỏ 9 hàng)
# Đã tạo: 311_segment_016.csv (904 hàng, loại bỏ 5 hàng)
# Đã tạo: 311_segment_017.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_019.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_020.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_021.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_022.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_023.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 311_segment_024.csv (910 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (26.2s < 30s)
#
# Đã tạo tổng cộng 24 file segment
# ✓ Hoàn thành ID 311: 24 segments
#
# ► Đang xử lý ID 312...
# File prefix: 312
# Khoảng thời gian từ Transcript: 1.4s - 780.6s
# Số dòng OpenFace sau khi lọc: 23618
# Bỏ qua segment 001 (loại bỏ 159 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 82 hàng > 30)
# Đã tạo: 312_segment_003.csv (906 hàng, loại bỏ 3 hàng)
# Đã tạo: 312_segment_004.csv (906 hàng, loại bỏ 3 hàng)
# Đã tạo: 312_segment_005.csv (895 hàng, loại bỏ 14 hàng)
# Đã tạo: 312_segment_006.csv (891 hàng, loại bỏ 19 hàng)
# Đã tạo: 312_segment_007.csv (901 hàng, loại bỏ 8 hàng)
# Đã tạo: 312_segment_008.csv (903 hàng, loại bỏ 6 hàng)
# Đã tạo: 312_segment_009.csv (882 hàng, loại bỏ 28 hàng)
# Đã tạo: 312_segment_010.csv (892 hàng, loại bỏ 17 hàng)
# Đã tạo: 312_segment_011.csv (906 hàng, loại bỏ 3 hàng)
# Bỏ qua segment 012 (loại bỏ 47 hàng > 30)
# Đã tạo: 312_segment_013.csv (879 hàng, loại bỏ 30 hàng)
# Đã tạo: 312_segment_014.csv (897 hàng, loại bỏ 12 hàng)
# Bỏ qua segment 015 (loại bỏ 42 hàng > 30)
# Đã tạo: 312_segment_016.csv (905 hàng, loại bỏ 5 hàng)
# Bỏ qua segment 017 (loại bỏ 88 hàng > 30)
# Đã tạo: 312_segment_018.csv (889 hàng, loại bỏ 20 hàng)
# Bỏ qua segment 019 (loại bỏ 85 hàng > 30)
# Đã tạo: 312_segment_020.csv (885 hàng, loại bỏ 24 hàng)
# Đã tạo: 312_segment_021.csv (898 hàng, loại bỏ 11 hàng)
# Đã tạo: 312_segment_022.csv (883 hàng, loại bỏ 27 hàng)
# Bỏ qua segment 023 (loại bỏ 45 hàng > 30)
# Đã tạo: 312_segment_024.csv (908 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 025 (loại bỏ 95 hàng > 30)
# Bỏ qua segment cuối (29.2s < 30s)
#
# Đã tạo tổng cộng 17 file segment
# ✓ Hoàn thành ID 312: 17 segments
#
# ► Đang xử lý ID 313...
# File prefix: 313
# Khoảng thời gian từ Transcript: 1.5s - 753.4s
# Số dòng OpenFace sau khi lọc: 22790
# Bỏ qua segment 001 (loại bỏ 103 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 154 hàng > 30)
# Đã tạo: 313_segment_003.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_004.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_006.csv (908 hàng, loại bỏ 2 hàng)
# Đã tạo: 313_segment_007.csv (908 hàng, loại bỏ 1 hàng)
# Đã tạo: 313_segment_008.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_009.csv (909 hàng, loại bỏ 1 hàng)
# Đã tạo: 313_segment_010.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_011.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_012.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_013.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_014.csv (906 hàng, loại bỏ 3 hàng)
# Đã tạo: 313_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_016.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_017.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_019.csv (909 hàng, loại bỏ 1 hàng)
# Đã tạo: 313_segment_020.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 313_segment_021.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_022.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_023.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 313_segment_024.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 025 (loại bỏ 103 hàng > 30)
# Bỏ qua segment cuối (1.9s < 30s)
#
# Đã tạo tổng cộng 22 file segment
# ✓ Hoàn thành ID 313: 22 segments
#
# ► Đang xử lý ID 314...
# File prefix: 314
# Khoảng thời gian từ Transcript: 1.5s - 1538.3s
# Số dòng OpenFace sau khi lọc: 46573
# Bỏ qua segment 001 (loại bỏ 59 hàng > 30)
# Đã tạo: 314_segment_002.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_003.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_004.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_006.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_007.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_008.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_009.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_010.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_011.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_012.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_013.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_016.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_017.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_018.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_019.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_020.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_021.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_022.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_023.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 314_segment_024.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_025.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_026.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_027.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_028.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_029.csv (902 hàng, loại bỏ 7 hàng)
# Bỏ qua segment 030 (loại bỏ 57 hàng > 30)
# Đã tạo: 314_segment_031.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_032.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_033.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_034.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_035.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_036.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_037.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_038.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_039.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_040.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 041 (loại bỏ 32 hàng > 30)
# Bỏ qua segment 042 (loại bỏ 31 hàng > 30)
# Đã tạo: 314_segment_043.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_044.csv (910 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 045 (loại bỏ 99 hàng > 30)
# Đã tạo: 314_segment_046.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_047.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_048.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_049.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 314_segment_050.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 051 (loại bỏ 74 hàng > 30)
# Bỏ qua segment cuối (6.8s < 30s)
#
# Đã tạo tổng cộng 45 file segment
# ✓ Hoàn thành ID 314: 45 segments
#
# ► Đang xử lý ID 315...
# File prefix: 315
# Khoảng thời gian từ Transcript: 0.3s - 974.2s
# Số dòng OpenFace sau khi lọc: 29516
# Bỏ qua segment 001 (loại bỏ 273 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 69 hàng > 30)
# Đã tạo: 315_segment_003.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 315_segment_004.csv (906 hàng, loại bỏ 3 hàng)
# Đã tạo: 315_segment_005.csv (905 hàng, loại bỏ 5 hàng)
# Đã tạo: 315_segment_006.csv (881 hàng, loại bỏ 28 hàng)
# Đã tạo: 315_segment_007.csv (908 hàng, loại bỏ 1 hàng)
# Đã tạo: 315_segment_008.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 315_segment_009.csv (888 hàng, loại bỏ 21 hàng)
# Đã tạo: 315_segment_010.csv (898 hàng, loại bỏ 12 hàng)
# Bỏ qua segment 011 (loại bỏ 31 hàng > 30)
# Đã tạo: 315_segment_012.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 315_segment_013.csv (889 hàng, loại bỏ 20 hàng)
# Bỏ qua segment 014 (loại bỏ 42 hàng > 30)
# Bỏ qua segment 015 (loại bỏ 99 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 99 hàng > 30)
# Đã tạo: 315_segment_017.csv (899 hàng, loại bỏ 10 hàng)
# Đã tạo: 315_segment_018.csv (908 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 019 (loại bỏ 35 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 31 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 72 hàng > 30)
# Đã tạo: 315_segment_022.csv (902 hàng, loại bỏ 7 hàng)
# Đã tạo: 315_segment_023.csv (882 hàng, loại bỏ 27 hàng)
# Bỏ qua segment 024 (loại bỏ 49 hàng > 30)
# Đã tạo: 315_segment_025.csv (899 hàng, loại bỏ 10 hàng)
# Đã tạo: 315_segment_026.csv (887 hàng, loại bỏ 22 hàng)
# Đã tạo: 315_segment_027.csv (901 hàng, loại bỏ 8 hàng)
# Đã tạo: 315_segment_028.csv (881 hàng, loại bỏ 28 hàng)
# Đã tạo: 315_segment_029.csv (909 hàng, loại bỏ 1 hàng)
# Đã tạo: 315_segment_030.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 315_segment_031.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 032 (loại bỏ 54 hàng > 30)
# Bỏ qua segment cuối (13.9s < 30s)
#
# Đã tạo tổng cộng 21 file segment
# ✓ Hoàn thành ID 315: 21 segments
#
# ► Đang xử lý ID 316...
# File prefix: 316
# Khoảng thời gian từ Transcript: 19.1s - 856.8s
# Số dòng OpenFace sau khi lọc: 25389
# Đã tạo: 316_segment_001.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_002.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_003.csv (880 hàng, loại bỏ 29 hàng)
# Đã tạo: 316_segment_004.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_006.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_007.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_008.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_009.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_010.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_011.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_012.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_013.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_016.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_017.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_019.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_020.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_021.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 022 (loại bỏ 58 hàng > 30)
# Đã tạo: 316_segment_023.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_024.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_025.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_026.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 316_segment_027.csv (903 hàng, loại bỏ 6 hàng)
# Bỏ qua segment cuối (27.7s < 30s)
#
# Đã tạo tổng cộng 26 file segment
# ✓ Hoàn thành ID 316: 26 segments
#
# ► Đang xử lý ID 317...
# File prefix: 317
# Khoảng thời gian từ Transcript: 3.5s - 767.4s
# Số dòng OpenFace sau khi lọc: 23152
# Đã tạo: 317_segment_001.csv (891 hàng, loại bỏ 18 hàng)
# Đã tạo: 317_segment_002.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_003.csv (904 hàng, loại bỏ 5 hàng)
# Đã tạo: 317_segment_004.csv (908 hàng, loại bỏ 2 hàng)
# Đã tạo: 317_segment_005.csv (904 hàng, loại bỏ 5 hàng)
# Đã tạo: 317_segment_006.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_007.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_008.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_009.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_010.csv (893 hàng, loại bỏ 16 hàng)
# Đã tạo: 317_segment_011.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 012 (loại bỏ 104 hàng > 30)
# Đã tạo: 317_segment_013.csv (901 hàng, loại bỏ 9 hàng)
# Bỏ qua segment 014 (loại bỏ 77 hàng > 30)
# Đã tạo: 317_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_016.csv (885 hàng, loại bỏ 24 hàng)
# Đã tạo: 317_segment_017.csv (901 hàng, loại bỏ 9 hàng)
# Bỏ qua segment 018 (loại bỏ 50 hàng > 30)
# Đã tạo: 317_segment_019.csv (895 hàng, loại bỏ 14 hàng)
# Đã tạo: 317_segment_020.csv (902 hàng, loại bỏ 7 hàng)
# Đã tạo: 317_segment_021.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 317_segment_022.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 317_segment_023.csv (881 hàng, loại bỏ 28 hàng)
# Đã tạo: 317_segment_024.csv (902 hàng, loại bỏ 7 hàng)
# Đã tạo: 317_segment_025.csv (899 hàng, loại bỏ 11 hàng)
# Bỏ qua segment cuối (13.9s < 30s)
#
# Đã tạo tổng cộng 22 file segment
# ✓ Hoàn thành ID 317: 22 segments
#
# ► Đang xử lý ID 318...
# File prefix: 318
# Khoảng thời gian từ Transcript: 0.7000000000000001s - 546.8s
# Số dòng OpenFace sau khi lọc: 16551
# Đã tạo: 318_segment_001.csv (902 hàng, loại bỏ 7 hàng)
# Đã tạo: 318_segment_002.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 318_segment_003.csv (899 hàng, loại bỏ 10 hàng)
# Đã tạo: 318_segment_004.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_006.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_007.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 318_segment_008.csv (906 hàng, loại bỏ 4 hàng)
# Đã tạo: 318_segment_009.csv (907 hàng, loại bỏ 2 hàng)
# Đã tạo: 318_segment_010.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_011.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_012.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_013.csv (900 hàng, loại bỏ 9 hàng)
# Đã tạo: 318_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 318_segment_016.csv (895 hàng, loại bỏ 15 hàng)
# Đã tạo: 318_segment_017.csv (882 hàng, loại bỏ 27 hàng)
# Đã tạo: 318_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (6.1s < 30s)
#
# Đã tạo tổng cộng 18 file segment
# ✓ Hoàn thành ID 318: 18 segments
#
# ► Đang xử lý ID 319...
# File prefix: 319
# Khoảng thời gian từ Transcript: 6.8s - 678.0s
# Số dòng OpenFace sau khi lọc: 20345
# Bỏ qua segment 001 (loại bỏ 156 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 57 hàng > 30)
# Bỏ qua segment 003 (loại bỏ 147 hàng > 30)
# Bỏ qua segment 004 (loại bỏ 762 hàng > 30)
# Bỏ qua segment 005 (loại bỏ 454 hàng > 30)
# Bỏ qua segment 006 (loại bỏ 415 hàng > 30)
# Bỏ qua segment 007 (loại bỏ 396 hàng > 30)
# Bỏ qua segment 008 (loại bỏ 320 hàng > 30)
# Bỏ qua segment 009 (loại bỏ 523 hàng > 30)
# Bỏ qua segment 010 (loại bỏ 539 hàng > 30)
# Bỏ qua segment 011 (loại bỏ 692 hàng > 30)
# Bỏ qua segment 012 (loại bỏ 652 hàng > 30)
# Bỏ qua segment 013 (loại bỏ 652 hàng > 30)
# Bỏ qua segment 014 (loại bỏ 393 hàng > 30)
# Bỏ qua segment 015 (loại bỏ 638 hàng > 30)
# Bỏ qua segment 016 (loại bỏ 481 hàng > 30)
# Bỏ qua segment 017 (loại bỏ 603 hàng > 30)
# Bỏ qua segment 018 (loại bỏ 325 hàng > 30)
# Bỏ qua segment 019 (loại bỏ 495 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 432 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 213 hàng > 30)
# Bỏ qua segment 022 (loại bỏ 427 hàng > 30)
# Bỏ qua segment cuối (11.2s < 30s)
#
# Đã tạo tổng cộng 0 file segment
# ✓ Hoàn thành ID 319: 0 segments
#
# ► Đang xử lý ID 320...
# File prefix: 320
# Khoảng thời gian từ Transcript: 6.7s - 834.3s
# Số dòng OpenFace sau khi lọc: 25082
# Bỏ qua segment 001 (loại bỏ 69 hàng > 30)
# Đã tạo: 320_segment_002.csv (896 hàng, loại bỏ 13 hàng)
# Bỏ qua segment 003 (loại bỏ 50 hàng > 30)
# Đã tạo: 320_segment_004.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_005.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_006.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_007.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_008.csv (880 hàng, loại bỏ 29 hàng)
# Đã tạo: 320_segment_009.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_010.csv (908 hàng, loại bỏ 1 hàng)
# Đã tạo: 320_segment_011.csv (882 hàng, loại bỏ 27 hàng)
# Đã tạo: 320_segment_012.csv (906 hàng, loại bỏ 3 hàng)
# Đã tạo: 320_segment_013.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_014.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_015.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_016.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_017.csv (885 hàng, loại bỏ 25 hàng)
# Đã tạo: 320_segment_018.csv (909 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_019.csv (891 hàng, loại bỏ 18 hàng)
# Bỏ qua segment 020 (loại bỏ 58 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 41 hàng > 30)
# Đã tạo: 320_segment_022.csv (886 hàng, loại bỏ 23 hàng)
# Bỏ qua segment 023 (loại bỏ 33 hàng > 30)
# Đã tạo: 320_segment_024.csv (905 hàng, loại bỏ 4 hàng)
# Đã tạo: 320_segment_025.csv (910 hàng, loại bỏ 0 hàng)
# Đã tạo: 320_segment_026.csv (909 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 027 (loại bỏ 84 hàng > 30)
# Bỏ qua segment cuối (17.6s < 30s)
#
# Đã tạo tổng cộng 21 file segment
# ✓ Hoàn thành ID 320: 21 segments
#
# ► Đang xử lý ID 321...
# File prefix: 321
# Khoảng thời gian từ Transcript: 5.7s - 810.7s
# Số dòng OpenFace sau khi lọc: 24151
# Bỏ qua segment 001 (loại bỏ 42 hàng > 30)
# Đã tạo: 321_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_010.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 321_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_023.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 321_segment_024.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 321_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 321_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (25.0s < 30s)
#
# Đã tạo tổng cộng 25 file segment
# ✓ Hoàn thành ID 321: 25 segments
#
# ► Đang xử lý ID 322...
# File prefix: 322
# Khoảng thời gian từ Transcript: 1.9s - 1020.4s
# Số dòng OpenFace sau khi lọc: 30556
# Bỏ qua segment 001 (loại bỏ 55 hàng > 30)
# Đã tạo: 322_segment_002.csv (884 hàng, loại bỏ 16 hàng)
# Đã tạo: 322_segment_003.csv (887 hàng, loại bỏ 13 hàng)
# Đã tạo: 322_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_005.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 322_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_008.csv (873 hàng, loại bỏ 27 hàng)
# Đã tạo: 322_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_011.csv (886 hàng, loại bỏ 14 hàng)
# Đã tạo: 322_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_014.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 322_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_023.csv (893 hàng, loại bỏ 7 hàng)
# Bỏ qua segment 024 (loại bỏ 77 hàng > 30)
# Đã tạo: 322_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_026.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 322_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 028 (loại bỏ 54 hàng > 30)
# Đã tạo: 322_segment_029.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_030.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_031.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 322_segment_032.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 322_segment_033.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (28.5s < 30s)
#
# Đã tạo tổng cộng 30 file segment
# ✓ Hoàn thành ID 322: 30 segments
#
# ► Đang xử lý ID 323...
# File prefix: 323
# Khoảng thời gian từ Transcript: 32.1s - 824.3s
# Số dòng OpenFace sau khi lọc: 23767
# Bỏ qua segment 001 (loại bỏ 83 hàng > 30)
# Đã tạo: 323_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_003.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 323_segment_004.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 323_segment_005.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 323_segment_006.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 323_segment_007.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 323_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_009.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 323_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 011 (loại bỏ 32 hàng > 30)
# Đã tạo: 323_segment_012.csv (884 hàng, loại bỏ 16 hàng)
# Đã tạo: 323_segment_013.csv (892 hàng, loại bỏ 8 hàng)
# Đã tạo: 323_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_015.csv (899 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 016 (loại bỏ 44 hàng > 30)
# Đã tạo: 323_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_019.csv (892 hàng, loại bỏ 8 hàng)
# Đã tạo: 323_segment_020.csv (887 hàng, loại bỏ 13 hàng)
# Bỏ qua segment 021 (loại bỏ 73 hàng > 30)
# Đã tạo: 323_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 323_segment_023.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 323_segment_024.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 323_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 026 (loại bỏ 116 hàng > 30)
# Bỏ qua segment cuối (12.2s < 30s)
#
# Đã tạo tổng cộng 21 file segment
# ✓ Hoàn thành ID 323: 21 segments
#
# ► Đang xử lý ID 324...
# File prefix: 324
# Khoảng thời gian từ Transcript: 0.7000000000000001s - 708.9s
# Số dòng OpenFace sau khi lọc: 21246
# Đã tạo: 324_segment_001.csv (869 hàng, loại bỏ 30 hàng)
# Bỏ qua segment 002 (loại bỏ 38 hàng > 30)
# Đã tạo: 324_segment_003.csv (888 hàng, loại bỏ 12 hàng)
# Bỏ qua segment 004 (loại bỏ 48 hàng > 30)
# Đã tạo: 324_segment_005.csv (879 hàng, loại bỏ 21 hàng)
# Bỏ qua segment 006 (loại bỏ 93 hàng > 30)
# Đã tạo: 324_segment_007.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 324_segment_008.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 324_segment_009.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 324_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 324_segment_011.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 324_segment_012.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 324_segment_013.csv (879 hàng, loại bỏ 21 hàng)
# Đã tạo: 324_segment_014.csv (889 hàng, loại bỏ 11 hàng)
# Bỏ qua segment 015 (loại bỏ 42 hàng > 30)
# Đã tạo: 324_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 017 (loại bỏ 55 hàng > 30)
# Đã tạo: 324_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 324_segment_019.csv (887 hàng, loại bỏ 13 hàng)
# Đã tạo: 324_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 324_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 324_segment_022.csv (899 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 023 (loại bỏ 40 hàng > 30)
# Bỏ qua segment cuối (18.2s < 30s)
#
# Đã tạo tổng cộng 17 file segment
# ✓ Hoàn thành ID 324: 17 segments
#
# ► Đang xử lý ID 325...
# File prefix: 325
# Khoảng thời gian từ Transcript: 8.6s - 847.4s
# Số dòng OpenFace sau khi lọc: 25165
# Đã tạo: 325_segment_001.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 325_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 325_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment cuối (28.8s < 30s)
#
# Đã tạo tổng cộng 27 file segment
# ✓ Hoàn thành ID 325: 27 segments
#
# ► Đang xử lý ID 326...
# File prefix: 326
# Khoảng thời gian từ Transcript: 0.7000000000000001s - 693.6s
# Số dòng OpenFace sau khi lọc: 20787
# Bỏ qua segment 001 (loại bỏ 75 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 284 hàng > 30)
# Đã tạo: 326_segment_003.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 326_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 326_segment_005.csv (876 hàng, loại bỏ 24 hàng)
# Bỏ qua segment 006 (loại bỏ 137 hàng > 30)
# Bỏ qua segment 007 (loại bỏ 52 hàng > 30)
# Đã tạo: 326_segment_008.csv (875 hàng, loại bỏ 25 hàng)
# Bỏ qua segment 009 (loại bỏ 38 hàng > 30)
# Bỏ qua segment 010 (loại bỏ 31 hàng > 30)
# Bỏ qua segment 011 (loại bỏ 90 hàng > 30)
# Bỏ qua segment 012 (loại bỏ 71 hàng > 30)
# Bỏ qua segment 013 (loại bỏ 92 hàng > 30)
# Bỏ qua segment 014 (loại bỏ 113 hàng > 30)
# Bỏ qua segment 015 (loại bỏ 36 hàng > 30)
# Đã tạo: 326_segment_016.csv (897 hàng, loại bỏ 3 hàng)
# Bỏ qua segment 017 (loại bỏ 39 hàng > 30)
# Bỏ qua segment 018 (loại bỏ 80 hàng > 30)
# Bỏ qua segment 019 (loại bỏ 77 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 142 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 110 hàng > 30)
# Bỏ qua segment 022 (loại bỏ 233 hàng > 30)
# Bỏ qua segment 023 (loại bỏ 262 hàng > 30)
# Bỏ qua segment cuối (2.9s < 30s)
#
# Đã tạo tổng cộng 5 file segment
# ✓ Hoàn thành ID 326: 5 segments
#
# ► Đang xử lý ID 327...
# File prefix: 327
# Khoảng thời gian từ Transcript: 0.4s - 676.2s
# Số dòng OpenFace sau khi lọc: 20275
# Đã tạo: 327_segment_001.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 327_segment_002.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 327_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_006.csv (889 hàng, loại bỏ 11 hàng)
# Đã tạo: 327_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 014 (loại bỏ 71 hàng > 30)
# Đã tạo: 327_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 327_segment_022.csv (899 hàng, loại bỏ 1 hàng)
# Bỏ qua segment cuối (15.8s < 30s)
#
# Đã tạo tổng cộng 21 file segment
# ✓ Hoàn thành ID 327: 21 segments
#
# ► Đang xử lý ID 328...
# File prefix: 328
# Khoảng thời gian từ Transcript: 8.3s - 1058.4s
# Số dòng OpenFace sau khi lọc: 31504
# Đã tạo: 328_segment_001.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 328_segment_002.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 328_segment_003.csv (890 hàng, loại bỏ 10 hàng)
# Đã tạo: 328_segment_004.csv (875 hàng, loại bỏ 25 hàng)
# ...
# Đã tạo: 696_segment_004.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 696_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_009.csv (889 hàng, loại bỏ 11 hàng)
# Đã tạo: 696_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_017.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 696_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 696_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 024 (loại bỏ 84 hàng > 30)
# Bỏ qua segment 025 (loại bỏ 293 hàng > 30)
# Bỏ qua segment cuối (8.3s < 30s)
#
# Đã tạo tổng cộng 23 file segment
# ✓ Hoàn thành ID 696: 23 segments
# ⊘ Bỏ qua 697: Không tìm thấy file Transcript
#
# ► Đang xử lý ID 698...
# File prefix: 698
# Khoảng thời gian từ Transcript: 2.6s - 1416.7s
# Số dòng OpenFace sau khi lọc: 42424
# Bỏ qua segment 001 (loại bỏ 65 hàng > 30)
# Bỏ qua segment 002 (loại bỏ 54 hàng > 30)
# Đã tạo: 698_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_006.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 698_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_009.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_010.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_011.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 698_segment_012.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_013.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_014.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 698_segment_015.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_016.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 018 (loại bỏ 54 hàng > 30)
# Đã tạo: 698_segment_019.csv (889 hàng, loại bỏ 11 hàng)
# Đã tạo: 698_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_021.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 698_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_023.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_025.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_026.csv (888 hàng, loại bỏ 12 hàng)
# Đã tạo: 698_segment_027.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 698_segment_028.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_029.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_030.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_031.csv (890 hàng, loại bỏ 10 hàng)
# Đã tạo: 698_segment_032.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 698_segment_033.csv (884 hàng, loại bỏ 16 hàng)
# Đã tạo: 698_segment_034.csv (883 hàng, loại bỏ 17 hàng)
# Đã tạo: 698_segment_035.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_036.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_037.csv (895 hàng, loại bỏ 5 hàng)
# Đã tạo: 698_segment_038.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_039.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_040.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 698_segment_041.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 698_segment_042.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_043.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 698_segment_044.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 698_segment_045.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 698_segment_046.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 047 (loại bỏ 69 hàng > 30)
# Bỏ qua segment cuối (4.1s < 30s)
#
# Đã tạo tổng cộng 43 file segment
# ✓ Hoàn thành ID 698: 43 segments
#
# ► Đang xử lý ID 699...
# File prefix: 699
# Khoảng thời gian từ Transcript: 1.7000000000000002s - 698.6s
# Số dòng OpenFace sau khi lọc: 20907
# Bỏ qua segment 001 (loại bỏ 35 hàng > 30)
# Đã tạo: 699_segment_002.csv (874 hàng, loại bỏ 26 hàng)
# Bỏ qua segment 003 (loại bỏ 138 hàng > 30)
# Đã tạo: 699_segment_004.csv (887 hàng, loại bỏ 13 hàng)
# Đã tạo: 699_segment_005.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 699_segment_006.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 699_segment_007.csv (886 hàng, loại bỏ 14 hàng)
# Đã tạo: 699_segment_008.csv (881 hàng, loại bỏ 19 hàng)
# Bỏ qua segment 009 (loại bỏ 64 hàng > 30)
# Bỏ qua segment 010 (loại bỏ 53 hàng > 30)
# Đã tạo: 699_segment_011.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 699_segment_012.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 699_segment_013.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 699_segment_014.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 699_segment_015.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 699_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 699_segment_017.csv (880 hàng, loại bỏ 20 hàng)
# Bỏ qua segment 018 (loại bỏ 118 hàng > 30)
# Bỏ qua segment 019 (loại bỏ 86 hàng > 30)
# Bỏ qua segment 020 (loại bỏ 129 hàng > 30)
# Bỏ qua segment 021 (loại bỏ 47 hàng > 30)
# Đã tạo: 699_segment_022.csv (892 hàng, loại bỏ 8 hàng)
# Đã tạo: 699_segment_023.csv (891 hàng, loại bỏ 9 hàng)
# Bỏ qua segment cuối (6.9s < 30s)
#
# Đã tạo tổng cộng 15 file segment
# ✓ Hoàn thành ID 699: 15 segments
# ⊘ Bỏ qua 700: Không tìm thấy file Transcript
# ⊘ Bỏ qua 701: Không tìm thấy file Transcript
# ⊘ Bỏ qua 702: Không tìm thấy file Transcript
# ⊘ Bỏ qua 703: Không tìm thấy file Transcript
# ⊘ Bỏ qua 704: Không tìm thấy file Transcript
#
# ► Đang xử lý ID 705...
# File prefix: 705
# Khoảng thời gian từ Transcript: 1.0s - 684.7s
# Số dòng OpenFace sau khi lọc: 20512
# Bỏ qua segment 001 (loại bỏ 39 hàng > 30)
# Đã tạo: 705_segment_002.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_005.csv (878 hàng, loại bỏ 22 hàng)
# Đã tạo: 705_segment_006.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 705_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 008 (loại bỏ 53 hàng > 30)
# Đã tạo: 705_segment_009.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 705_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 705_segment_013.csv (899 hàng, loại bỏ 1 hàng)
# Bỏ qua segment 014 (loại bỏ 38 hàng > 30)
# Đã tạo: 705_segment_015.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 705_segment_016.csv (883 hàng, loại bỏ 17 hàng)
# Đã tạo: 705_segment_017.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 705_segment_018.csv (897 hàng, loại bỏ 3 hàng)
# Đã tạo: 705_segment_019.csv (892 hàng, loại bỏ 8 hàng)
# Đã tạo: 705_segment_020.csv (889 hàng, loại bỏ 11 hàng)
# Đã tạo: 705_segment_021.csv (895 hàng, loại bỏ 5 hàng)
# Bỏ qua segment 022 (loại bỏ 57 hàng > 30)
# Bỏ qua segment cuối (23.7s < 30s)
#
# Đã tạo tổng cộng 18 file segment
# ✓ Hoàn thành ID 705: 18 segments
# ⊘ Bỏ qua 706: Không tìm thấy file Transcript
# ⊘ Bỏ qua 707: Không tìm thấy file Transcript
# ⊘ Bỏ qua 708: Không tìm thấy file Transcript
#
# ► Đang xử lý ID 709...
# File prefix: 709
# Khoảng thời gian từ Transcript: 6.5s - 818.8s
# Số dòng OpenFace sau khi lọc: 24370
# Đã tạo: 709_segment_001.csv (874 hàng, loại bỏ 26 hàng)
# Bỏ qua segment 002 (loại bỏ 49 hàng > 30)
# Đã tạo: 709_segment_003.csv (887 hàng, loại bỏ 13 hàng)
# Đã tạo: 709_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_006.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 709_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_010.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 709_segment_011.csv (898 hàng, loại bỏ 2 hàng)
# Đã tạo: 709_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_017.csv (891 hàng, loại bỏ 9 hàng)
# Đã tạo: 709_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_022.csv (899 hàng, loại bỏ 1 hàng)
# Đã tạo: 709_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 709_segment_025.csv (893 hàng, loại bỏ 7 hàng)
# Đã tạo: 709_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 027 (loại bỏ 73 hàng > 30)
# Bỏ qua segment cuối (2.3s < 30s)
#
# Đã tạo tổng cộng 25 file segment
# ✓ Hoàn thành ID 709: 25 segments
# ⊘ Bỏ qua 710: Không tìm thấy file Transcript
# ⊘ Bỏ qua 711: Không tìm thấy file Transcript
# ⊘ Bỏ qua 712: Không tìm thấy file Transcript
# ⊘ Bỏ qua 713: Không tìm thấy file Transcript
# ⊘ Bỏ qua 714: Không tìm thấy file Transcript
# ⊘ Bỏ qua 715: Không tìm thấy file Transcript
#
# ► Đang xử lý ID 716...
# File prefix: 716
# Khoảng thời gian từ Transcript: 7.7s - 967.7s
# Số dòng OpenFace sau khi lọc: 28801
# Đã tạo: 716_segment_001.csv (894 hàng, loại bỏ 6 hàng)
# Đã tạo: 716_segment_002.csv (896 hàng, loại bỏ 4 hàng)
# Đã tạo: 716_segment_003.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_004.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_005.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_006.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_007.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_008.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_009.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_010.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_011.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_012.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_013.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_014.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_015.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_016.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_017.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_018.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_019.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_020.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_021.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_022.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_023.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_024.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_025.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_026.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_027.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_028.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_029.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_030.csv (900 hàng, loại bỏ 0 hàng)
# Đã tạo: 716_segment_031.csv (900 hàng, loại bỏ 0 hàng)
# Bỏ qua segment 032 (loại bỏ 162 hàng > 30)
#
# Đã tạo tổng cộng 31 file segment
# ✓ Hoàn thành ID 716: 31 segments
#
# ================================================================================
#
# TÓM TẮT:
#   • Đã xử lý thành công: 218 files
#   • Đã bỏ qua: 199 files
#   • Tổng segments tạo ra: 5461
#
# ================================================================================
# CHI TIẾT KẾT QUẢ:
#   300_P: 19 segments
#   301_P: 27 segments
#   302_P: 15 segments
#   303_P: 27 segments
#   304_P: 10 segments
#   305_P: 54 segments
#   306_P: 27 segments
#   307_P: 33 segments
#   308_P: 21 segments
#   309_P: 18 segments
#   310_P: 3 segments
#   311_P: 24 segments
#   312_P: 17 segments
#   313_P: 22 segments
#   314_P: 45 segments
#   315_P: 21 segments
#   316_P: 26 segments
#   317_P: 22 segments
#   318_P: 18 segments
#   319_P: 0 segments
#   320_P: 21 segments
#   321_P: 25 segments
#   322_P: 30 segments
#   323_P: 21 segments
#   324_P: 17 segments
#   325_P: 27 segments
#   326_P: 5 segments
#   327_P: 21 segments
#   328_P: 11 segments
#   329_P: 21 segments
#   330_P: 13 segments
#   331_P: 27 segments
#   332_P: 27 segments
#   333_P: 30 segments
#   334_P: 20 segments
#   335_P: 26 segments
#   336_P: 21 segments
#   337_P: 61 segments
#   338_P: 17 segments
#   339_P: 27 segments
#   340_P: 18 segments
#   341_P: 25 segments
#   343_P: 22 segments
#   344_P: 0 segments
#   345_P: 24 segments
#   346_P: 36 segments
#   347_P: 18 segments
#   348_P: 22 segments
#   349_P: 16 segments
#   350_P: 20 segments
#   351_P: 24 segments
#   352_P: 24 segments
#   353_P: 22 segments
#   354_P: 17 segments
#   355_P: 15 segments
#   356_P: 17 segments
#   357_P: 4 segments
#   358_P: 15 segments
#   359_P: 2 segments
#   360_P: 12 segments
#   361_P: 18 segments
#   362_P: 17 segments
#   363_P: 39 segments
#   364_P: 57 segments
#   365_P: 39 segments
#   366_P: 11 segments
#   367_P: 49 segments
#   368_P: 39 segments
#   369_P: 31 segments
#   370_P: 34 segments
#   371_P: 24 segments
#   372_P: 43 segments
#   373_P: 40 segments
#   374_P: 41 segments
#   375_P: 10 segments
#   376_P: 31 segments
#   377_P: 41 segments
#   378_P: 27 segments
#   379_P: 30 segments
#   380_P: 52 segments
#   381_P: 33 segments
#   382_P: 27 segments
#   383_P: 42 segments
#   384_P: 3 segments
#   385_P: 15 segments
#   386_P: 32 segments
#   387_P: 18 segments
#   388_P: 15 segments
#   389_P: 16 segments
#   390_P: 43 segments
#   391_P: 19 segments
#   392_P: 19 segments
#   393_P: 5 segments
#   395_P: 28 segments
#   396_P: 23 segments
#   397_P: 24 segments
#   399_P: 22 segments
#   400_P: 3 segments
#   401_P: 29 segments
#   402_P: 24 segments
#   403_P: 27 segments
#   404_P: 31 segments
#   405_P: 47 segments
#   406_P: 19 segments
#   407_P: 39 segments
#   408_P: 21 segments
#   409_P: 30 segments
#   410_P: 32 segments
#   411_P: 42 segments
#   412_P: 26 segments
#   413_P: 20 segments
#   414_P: 30 segments
#   415_P: 22 segments
#   416_P: 27 segments
#   417_P: 25 segments
#   418_P: 17 segments
#   419_P: 28 segments
#   420_P: 17 segments
#   421_P: 26 segments
#   422_P: 41 segments
#   423_P: 26 segments
#   424_P: 29 segments
#   425_P: 37 segments
#   426_P: 22 segments
#   427_P: 26 segments
#   428_P: 13 segments
#   429_P: 30 segments
#   430_P: 28 segments
#   431_P: 0 segments
#   432_P: 2 segments
#   433_P: 24 segments
#   434_P: 10 segments
#   435_P: 34 segments
#   436_P: 21 segments
#   437_P: 26 segments
#   438_P: 46 segments
#   439_P: 35 segments
#   440_P: 41 segments
#   441_P: 23 segments
#   442_P: 10 segments
#   443_P: 16 segments
#   444_P: 37 segments
#   445_P: 21 segments
#   446_P: 32 segments
#   447_P: 24 segments
#   448_P: 39 segments
#   449_P: 33 segments
#   450_P: 29 segments
#   451_P: 29 segments
#   452_P: 25 segments
#   453_P: 25 segments
#   454_P: 25 segments
#   455_P: 23 segments
#   456_P: 27 segments
#   457_P: 31 segments
#   458_P: 27 segments
#   459_P: 30 segments
#   461_P: 29 segments
#   462_P: 23 segments
#   463_P: 22 segments
#   464_P: 31 segments
#   465_P: 32 segments
#   466_P: 32 segments
#   467_P: 29 segments
#   468_P: 29 segments
#   469_P: 32 segments
#   470_P: 8 segments
#   471_P: 32 segments
#   472_P: 28 segments
#   473_P: 15 segments
#   474_P: 27 segments
#   475_P: 18 segments
#   476_P: 17 segments
#   477_P: 40 segments
#   478_P: 26 segments
#   479_P: 26 segments
#   480_P: 23 segments
#   481_P: 18 segments
#   482_P: 30 segments
#   483_P: 46 segments
#   484_P: 31 segments
#   485_P: 18 segments
#   486_P: 21 segments
#   487_P: 31 segments
#   488_P: 6 segments
#   489_P: 22 segments
#   490_P: 19 segments
#   491_P: 20 segments
#   492_P: 25 segments
#   602_P: 24 segments
#   604_P: 15 segments
#   617_P: 37 segments
#   624_P: 2 segments
#   633_P: 49 segments
#   636_P: 46 segments
#   637_P: 36 segments
#   638_P: 14 segments
#   640_P: 23 segments
#   641_P: 17 segments
#   649_P: 12 segments
#   655_P: 26 segments
#   658_P: 28 segments
#   659_P: 41 segments
#   661_P: 40 segments
#   673_P: 14 segments
#   677_P: 24 segments
#   680_P: 37 segments
#   682_P: 22 segments
#   684_P: 30 segments
#   688_P: 25 segments
#   689_P: 21 segments
#   691_P: 11 segments
#   696_P: 23 segments
#   698_P: 43 segments
#   699_P: 15 segments
#   705_P: 18 segments
#   709_P: 25 segments
#   716_P: 31 segments

# %%
import os
import shutil

# Thư mục gốc chứa các folder cần nén
base_dir = "/kaggle/working"

# Lặp qua tất cả các thư mục con trong base_dir
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    # Chỉ xử lý nếu là thư mục (bỏ qua file)
    if os.path.isdir(folder_path):
        zip_path = os.path.join(base_dir, folder_name)  # Không cần .zip, shutil tự thêm
        try:
            shutil.make_archive(zip_path, 'zip', folder_path)
            print(f"✅ Đã nén: {folder_name}.zip")
        except Exception as e:
            print(f"⚠️ Lỗi khi nén {folder_name}: {e}")
# Out:
# ✅ Đã nén: 464_P.zip
# ✅ Đã nén: 389_P.zip
# ✅ Đã nén: 343_P.zip
# ✅ Đã nén: 309_P.zip
# ✅ Đã nén: 423_P.zip
# ✅ Đã nén: 355_P.zip
# ✅ Đã nén: 461_P.zip
# ✅ Đã nén: 408_P.zip
# ✅ Đã nén: 473_P.zip
# ✅ Đã nén: 425_P.zip
# ✅ Đã nén: 465_P.zip
# ✅ Đã nén: 358_P.zip
# ✅ Đã nén: 305_P.zip
# ✅ Đã nén: 677_P.zip
# ✅ Đã nén: 414_P.zip
# ✅ Đã nén: 421_P.zip
# ✅ Đã nén: 383_P.zip
# ✅ Đã nén: 371_P.zip
# ✅ Đã nén: 454_P.zip
# ✅ Đã nén: 491_P.zip
# ✅ Đã nén: 406_P.zip
# ✅ Đã nén: 604_P.zip
# ✅ Đã nén: 370_P.zip
# ✅ Đã nén: 483_P.zip
# ✅ Đã nén: 471_P.zip
# ✅ Đã nén: 480_P.zip
# ✅ Đã nén: 640_P.zip
# ✅ Đã nén: 467_P.zip
# ✅ Đã nén: 350_P.zip
# ✅ Đã nén: 365_P.zip
# ✅ Đã nén: 432_P.zip
# ✅ Đã nén: 325_P.zip
# ✅ Đã nén: 399_P.zip
# ✅ Đã nén: 307_P.zip
# ✅ Đã nén: 351_P.zip
# ✅ Đã nén: 361_P.zip
# ✅ Đã nén: 440_P.zip
# ✅ Đã nén: 354_P.zip
# ✅ Đã nén: 439_P.zip
# ✅ Đã nén: 436_P.zip
# ✅ Đã nén: 479_P.zip
# ✅ Đã nén: 477_P.zip
# ✅ Đã nén: 459_P.zip
# ✅ Đã nén: 698_P.zip
# ✅ Đã nén: 340_P.zip
# ✅ Đã nén: 372_P.zip
# ✅ Đã nén: 661_P.zip
# ✅ Đã nén: 316_P.zip
# ✅ Đã nén: 633_P.zip
# ✅ Đã nén: 359_P.zip
# ✅ Đã nén: 490_P.zip
# ✅ Đã nén: 400_P.zip
# ✅ Đã nén: 417_P.zip
# ✅ Đã nén: 356_P.zip
# ✅ Đã nén: 435_P.zip
# ✅ Đã nén: 602_P.zip
# ✅ Đã nén: 324_P.zip
# ✅ Đã nén: 447_P.zip
# ✅ Đã nén: 682_P.zip
# ✅ Đã nén: 301_P.zip
# ✅ Đã nén: 637_P.zip
# ✅ Đã nén: 468_P.zip
# ✅ Đã nén: 419_P.zip
# ✅ Đã nén: 385_P.zip
# ✅ Đã nén: 402_P.zip
# ✅ Đã nén: 431_P.zip
# ✅ Đã nén: 362_P.zip
# ✅ Đã nén: 364_P.zip
# ✅ Đã nén: 332_P.zip
# ✅ Đã nén: 624_P.zip
# ✅ Đã nén: 306_P.zip
# ✅ Đã nén: 638_P.zip
# ✅ Đã nén: 321_P.zip
# ✅ Đã nén: 337_P.zip
# ✅ Đã nén: .virtual_documents.zip
# ✅ Đã nén: 478_P.zip
# ✅ Đã nén: 366_P.zip
# ✅ Đã nén: 699_P.zip
# ✅ Đã nén: 443_P.zip
# ✅ Đã nén: 330_P.zip
# ✅ Đã nén: 410_P.zip
# ✅ Đã nén: 338_P.zip
# ✅ Đã nén: 481_P.zip
# ✅ Đã nén: 300_P.zip
# ✅ Đã nén: 312_P.zip
# ✅ Đã nén: 412_P.zip
# ✅ Đã nén: 382_P.zip
# ✅ Đã nén: 317_P.zip
# ✅ Đã nén: 386_P.zip
# ✅ Đã nén: 655_P.zip
# ✅ Đã nén: 691_P.zip
# ✅ Đã nén: 485_P.zip
# ✅ Đã nén: 405_P.zip
# ✅ Đã nén: 689_P.zip
# ✅ Đã nén: 484_P.zip
# ✅ Đã nén: 636_P.zip
# ✅ Đã nén: 348_P.zip
# ✅ Đã nén: 304_P.zip
# ✅ Đã nén: 387_P.zip
# ✅ Đã nén: 458_P.zip
# ✅ Đã nén: 658_P.zip
# ✅ Đã nén: 457_P.zip
# ✅ Đã nén: 322_P.zip
# ✅ Đã nén: 680_P.zip
# ✅ Đã nén: 438_P.zip
# ✅ Đã nén: 345_P.zip
# ✅ Đã nén: 429_P.zip
# ✅ Đã nén: 446_P.zip
# ✅ Đã nén: 303_P.zip
# ✅ Đã nén: 450_P.zip
# ✅ Đã nén: 407_P.zip
# ✅ Đã nén: 320_P.zip
# ✅ Đã nén: 487_P.zip
# ✅ Đã nén: 368_P.zip
# ✅ Đã nén: 659_P.zip
# ✅ Đã nén: 452_P.zip
# ✅ Đã nén: 463_P.zip
# ✅ Đã nén: 474_P.zip
# ✅ Đã nén: 346_P.zip
# ✅ Đã nén: 442_P.zip
# ✅ Đã nén: 339_P.zip
# ✅ Đã nén: 336_P.zip
# ✅ Đã nén: 426_P.zip
# ✅ Đã nén: 352_P.zip
# ✅ Đã nén: 430_P.zip
# ✅ Đã nén: 448_P.zip
# ✅ Đã nén: 716_P.zip
# ✅ Đã nén: 428_P.zip
# ✅ Đã nén: 418_P.zip
# ✅ Đã nén: 466_P.zip
# ✅ Đã nén: 369_P.zip
# ✅ Đã nén: 344_P.zip
# ✅ Đã nén: 391_P.zip
# ✅ Đã nén: 335_P.zip
# ✅ Đã nén: 404_P.zip
# ✅ Đã nén: 310_P.zip
# ✅ Đã nén: 416_P.zip
# ✅ Đã nén: 302_P.zip
# ✅ Đã nén: 649_P.zip
# ✅ Đã nén: 327_P.zip
# ✅ Đã nén: 433_P.zip
# ✅ Đã nén: 403_P.zip
# ✅ Đã nén: 492_P.zip
# ✅ Đã nén: 376_P.zip
# ✅ Đã nén: 415_P.zip
# ✅ Đã nén: 449_P.zip
# ✅ Đã nén: 341_P.zip
# ✅ Đã nén: 363_P.zip
# ✅ Đã nén: 328_P.zip
# ✅ Đã nén: 319_P.zip
# ✅ Đã nén: 482_P.zip
# ✅ Đã nén: 390_P.zip
# ✅ Đã nén: 488_P.zip
# ✅ Đã nén: 334_P.zip
# ✅ Đã nén: 393_P.zip
# ✅ Đã nén: 315_P.zip
# ✅ Đã nén: 360_P.zip
# ✅ Đã nén: 318_P.zip
# ✅ Đã nén: 367_P.zip
# ✅ Đã nén: 401_P.zip
# ✅ Đã nén: 333_P.zip
# ✅ Đã nén: 684_P.zip
# ✅ Đã nén: 422_P.zip
# ✅ Đã nén: 472_P.zip
# ✅ Đã nén: 311_P.zip
# ✅ Đã nén: 455_P.zip
# ✅ Đã nén: 420_P.zip
# ✅ Đã nén: 413_P.zip
# ✅ Đã nén: 451_P.zip
# ✅ Đã nén: 453_P.zip
# ✅ Đã nén: 314_P.zip
# ✅ Đã nén: 617_P.zip
# ✅ Đã nén: 434_P.zip
# ✅ Đã nén: 427_P.zip
# ✅ Đã nén: 380_P.zip
# ✅ Đã nén: 411_P.zip
# ✅ Đã nén: 323_P.zip
# ✅ Đã nén: 709_P.zip
# ✅ Đã nén: 489_P.zip
# ✅ Đã nén: 313_P.zip
# ✅ Đã nén: 384_P.zip
# ✅ Đã nén: 357_P.zip
# ✅ Đã nén: 673_P.zip
# ✅ Đã nén: 374_P.zip
# ✅ Đã nén: 424_P.zip
# ✅ Đã nén: 329_P.zip
# ✅ Đã nén: 441_P.zip
# ✅ Đã nén: 396_P.zip
# ✅ Đã nén: 373_P.zip
# ✅ Đã nén: 688_P.zip
# ✅ Đã nén: 378_P.zip
# ✅ Đã nén: 308_P.zip
# ✅ Đã nén: 347_P.zip
# ✅ Đã nén: 475_P.zip
# ✅ Đã nén: 470_P.zip
# ✅ Đã nén: 377_P.zip
# ✅ Đã nén: 445_P.zip
# ✅ Đã nén: 395_P.zip
# ✅ Đã nén: 444_P.zip
# ✅ Đã nén: 379_P.zip
# ✅ Đã nén: 641_P.zip
# ✅ Đã nén: 397_P.zip
# ✅ Đã nén: 476_P.zip
# ✅ Đã nén: 469_P.zip
# ✅ Đã nén: 409_P.zip
# ✅ Đã nén: 388_P.zip
# ✅ Đã nén: 486_P.zip
# ✅ Đã nén: 326_P.zip
# ✅ Đã nén: 462_P.zip
# ✅ Đã nén: 381_P.zip
# ✅ Đã nén: 437_P.zip
# ✅ Đã nén: 705_P.zip
# ✅ Đã nén: 375_P.zip
# ✅ Đã nén: 456_P.zip
# ✅ Đã nén: 331_P.zip
# ✅ Đã nén: 392_P.zip
# ✅ Đã nén: 349_P.zip
# ✅ Đã nén: 353_P.zip
# ✅ Đã nén: 696_P.zip
